# %% [markdown]
# # 1-click Recruitment Outreach Pipeline (Starter)
# Run top-to-bottom. It installs deps, accepts your job/profile JSON, and generates outreach output.

# %%
# No dependency install needed (stdlib-only pipeline).
# Optional: !pip -q install requests beautifulsoup4

# %%
import json, textwrap, pathlib
pathlib.Path('input.json').write_text(textwrap.dedent('''
{
  "job": {
    "title": "Senior Machine Learning Engineer",
    "company": "ExampleAI",
    "url": "https://example.com/jobs/ml-engineer",
    "description": "Paste job description here (optional if URL works)."
  },
  "profile": {
    "name": "Your Name",
    "target_role": "Machine Learning Engineer",
    "skills": ["Python", "NLP", "LLM", "AWS"],
    "years_experience": "5+ years",
    "summary": "Production ML systems."
  },
  "company_domain": "exampleai.com"
}
''').strip())
print('Edit input.json then run the next cell.')

# %%
# Upload recruiting_pipeline.py to Colab, then run:
# !python recruiting_pipeline.py --input input.json --output report.md
print(open('report.md').read()[:4000])
